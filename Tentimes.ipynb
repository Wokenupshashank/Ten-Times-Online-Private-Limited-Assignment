# %% [markdown]
# ## Ten Times online Assignment

# %% [markdown]
# Objective: Build an application that collects news articles from various RSS feeds (e.g: listed
# below), stores them in a database, and categorizes them into predefined categories.
# Categories the news item should fall under are:
#
# ● Terrorism / protest / political unrest / riot
#
# ● Positive/Uplifting
#
# ● Natural Disasters
#
# ● Others

# %%
# importing libraries
import feedparser
import spacy
import pandas as pd

# Load the English NLP model
nlp = spacy.load("en_core_web_sm")

# List of RSS feed URLs
rss_feeds = [
    "http://rss.cnn.com/rss/cnn_topstories.rss",
    "http://qz.com/feed",
    "http://feeds.foxnews.com/foxnews/politics",
    "http://feeds.reuters.com/reuters/businessNews",
    "http://feeds.feedburner.com/NewshourWorld",
    "https://feeds.bbci.co.uk/news/world/asia/india/rss.xml"
]

# Function to fetch and parse an RSS feed
def parse_rss_feed(feed_url):
    feed = feedparser.parse(feed_url)
    parsed_articles = []

    for entry in feed.entries:
        title = entry.title
        link = entry.link

        parsed_articles.append({
            'Title': title,
            'Link': link
        })

    return parsed_articles

# Function to categorize titles using spaCy
def categorize_title(title):
    doc = nlp(title)

    # Check for named entities or other patterns in the title
    for ent in doc.ents:
        if ent.label_ in ['ORG', 'GPE']:
            return "Terrorism / Protest / Political Unrest / Riot"

    # Check for positive/uplifting keywords
    positive_keywords = ["positive", "uplifting", "inspiring"]
    if any(keyword in title.lower() for keyword in positive_keywords):
        return "Positive/Uplifting"

    # Check for natural disasters keywords
    natural_disasters_keywords = ["natural disasters", "earthquake", "flood", "hurricane"]
    if any(keyword in title.lower() for keyword in natural_disasters_keywords):
        return "Natural Disasters"

    return "Others"

# Parse all RSS feeds
all_articles = []
for feed_url in rss_feeds:
    articles = parse_rss_feed(feed_url)
    all_articles.extend(articles)

# Categorize and create a DataFrame
df = pd.DataFrame(all_articles)
df['Category'] = df['Title'].apply(categorize_title)

# Export the DataFrame to an Excel file
excel_file_path = "parsed_articles.xlsx"
df.to_excel(excel_file_path, index=False)

print(f"Excel file '{excel_file_path}' created successfully.")
# Out:
# Excel file 'parsed_articles.xlsx' created successfully.

# %%
data = pd.read_excel("C:/Users/soppoju narender/parsed_articles.xlsx")

# %%
data
# Out:
#                                                  Title  \
# 0    Some on-air claims about Dominion Voting Syste...
# 1    Dominion still has pending lawsuits against el...
# 2    Here are the 20 specific Fox broadcasts and tw...
# 3    Judge in Fox News-Dominion defamation trial: '...
# 4    'Difficult to say with a straight face': Tappe...
# ..                                                 ...
# 168  Crowds at India's new Ram temple day after ope...
# 169  Watch: Indian PM Modi inaugurates temple in Ay...
# 170     Watch: Plane gets jammed under bridge in India
# 171  Watch: Intruder jumps on table in Indian parli...
# 172  Watch: Moment worker is pulled from collapsed ...
#
#                                                   Link  \
# 0    https://www.cnn.com/business/live-news/fox-new...
# 1    https://www.cnn.com/business/live-news/fox-new...
# 2    https://www.cnn.com/2023/04/17/media/dominion-...
# 3    https://www.cnn.com/2023/04/18/media/fox-domin...
# 4    https://www.cnn.com/videos/politics/2023/04/18...
# ..                                                 ...
# 168  https://www.bbc.co.uk/news/world-asia-india-68...
# 169  https://www.bbc.co.uk/news/world-asia-india-68...
# 170  https://www.bbc.co.uk/news/world-asia-india-67...
# 171  https://www.bbc.co.uk/news/world-asia-india-67...
# 172  https://www.bbc.co.uk/news/world-asia-india-67...
#
#                                           Category
# 0    Terrorism / Protest / Political Unrest / Riot
# 1    Terrorism / Protest / Political Unrest / Riot
# 2    Terrorism / Protest / Political Unrest / Riot
# 3    Terrorism / Protest / Political Unrest / Riot
# 4    Terrorism / Protest / Political Unrest / Riot
# ..                                             ...
# 168  Terrorism / Protest / Political Unrest / Riot
# 169  Terrorism / Protest / Political Unrest / Riot
# 170  Terrorism / Protest / Political Unrest / Riot
# 171                                         Others
# 172                                         Others
#
# [173 rows x 3 columns]

# %%
data.loc[20:30]
# Out:
#                                                 Title  \
# 20  Two Russians claiming to be former Wagner comm...
# 21  'My stomach is hurting from laughing': Hear pa...
# 22  GOP prepared to block vote to replace Feinstei...
# 23  Oklahoma governor calls on officials to resign...
# 24        McCarthy slams Biden in handling of US debt
# 25  US warns Russia not to touch American nuclear ...
# 26  Repeated gunshots fired on live TV as ex-lawma...
# 27  FDA clears the way for additional bivalent boo...
# 28  Maine authorities detained a person of interes...
# 29  Southwest says flights resumed after delays ca...
# 30  Damar Hamlin cleared to resume football activi...
#
#                                                  Link  \
# 20  https://www.cnn.com/2023/04/17/europe/wagner-c...
# 21  https://www.cnn.com/videos/business/2023/04/18...
# 22  https://www.cnn.com/2023/04/18/politics/schume...
# 23  https://www.cnn.com/2023/04/18/us/mccurtain-co...
# 24  https://www.cnn.com/videos/politics/2023/04/18...
# 25  https://www.cnn.com/2023/04/18/politics/us-war...
# 26  https://www.cnn.com/videos/world/2023/04/18/in...
# 27  https://www.cnn.com/2023/04/18/health/fda-biva...
# 28  https://www.cnn.com/2023/04/18/us/maine-shooti...
# 29  https://www.cnn.com/travel/article/southwest-a...
# 30  https://www.cnn.com/2023/04/18/sport/damar-ham...
#
#                                          Category
# 20  Terrorism / Protest / Political Unrest / Riot
# 21  Terrorism / Protest / Political Unrest / Riot
# 22  Terrorism / Protest / Political Unrest / Riot
# 23  Terrorism / Protest / Political Unrest / Riot
# 24  Terrorism / Protest / Political Unrest / Riot
# 25  Terrorism / Protest / Political Unrest / Riot
# 26                                         Others
# 27  Terrorism / Protest / Political Unrest / Riot
# 28  Terrorism / Protest / Political Unrest / Riot
# 29  Terrorism / Protest / Political Unrest / Riot
# 30                                         Others
